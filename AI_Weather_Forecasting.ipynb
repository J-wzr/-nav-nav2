# %%
#pd.read_excel() reads all excel files, and sheet_name=None reads all multiple sheets in the excel file
#the data is categoried or separated into various months of the year 2020
data=pd.read_excel("/content/sample_data/Data.xlsx",sheet_name=None)
data['January 2020']
# Out:
#              January(2020)   Unnamed: 1  \
# 0                     DATE  Temperature
# 1      2020-01-01 00:00:00         29.3
# 2      2020-01-02 00:00:00           30
# 3      2020-01-03 00:00:00         30.6
# 4      2020-01-04 00:00:00         30.2
# 5      2020-01-05 00:00:00         28.5
# 6      2020-01-06 00:00:00         29.3
# 7      2020-01-07 00:00:00           29
# 8      2020-01-08 00:00:00           29
# 9      2020-01-09 00:00:00         28.2
# 10     2020-01-10 00:00:00           31
# 11     2020-01-11 00:00:00         30.9
# 12     2020-01-12 00:00:00         29.2
# 13     2020-01-13 00:00:00           29
# 14     2020-01-14 00:00:00         30.4
# 15     2020-01-15 00:00:00         30.6
# 16     2020-01-16 00:00:00         32.4
# 17     2020-01-17 00:00:00         32.6
# 18     2020-01-18 00:00:00         31.3
# 19     2020-01-19 00:00:00           28
# 20     2020-01-20 00:00:00           30
# 21     2020-01-21 00:00:00         31.2
# ...

# %%
import pandas as pd
# !pip install pyarrow
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

# %%
#Jonas Code to prepare data from Uganda 2020

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

#Only use to remove first line from CSV files
def prepareData(directory):
    fileNames = getFileNames(directory) 
    for file in fileNames:
        with open(file, 'r') as input:
            data = input.readlines()
        with open(file, 'w') as output:
            output.writelines(data[1:])
    return fileNames

#Get list of filenames in a directory
def getFileNames(directory):
    fileNames = os.listdir(directory)
    for i in range(len(fileNames)):
        fileNames[i] = directory+fileNames[i]  
    return fileNames

#Create list of dataFrames from files in name list
def getDataFrames(fileNames):
    dataframes = []
    for file in fileNames:
        df = pd.read_csv(file,sep=";")
        dataframes.append(df)
    return dataframes

# fileNames = getFileNames("../data/Ugandan Data 2020/")

# Was reading the Ugandan data
fileNames = getFileNames("/content/sample_data/") 
dfList = getDataFrames(fileNames)

#Combine dataframes for all months into a single dataframe
frame = pd.concat(dfList, axis=0, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-6de55227b06c> in <module>
#      37 # Was reading the Ugandan data
#      38 fileNames = getFileNames("/content/sample_data/") #
# ---> 39 dfList = getDataFrames(fileNames)
#      40
#      41 #Combine dataframes for all months into a single dataframe
#
# <ipython-input-13-6de55227b06c> in getDataFrames(fileNames)
#      29     dataframes = []
#      30     for file in fileNames:
# ---> 31         df = pd.read_csv(file,sep=";")
#      32         dataframes.append(df)
#      33     return dataframes
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
